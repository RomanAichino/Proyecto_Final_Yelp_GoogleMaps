# %% [markdown]
# # ETL Metadata Sitios Google Maps

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import json

# %% [markdown]
# ## 1. Analizamos la estructura de los archivos json.
#
# Observamos la estructura de los archivos .json, especialmente si son las mismas keys en cada archivo json.

# %%
df_metadata_1 = pd.read_json('/content/drive/MyDrive/google_maps/metadata_sitios/Copia de 1.json', lines=True)
df_metadata_1.iloc[0]
# Out:
# name                                                  Porter Pharmacy
# address             Porter Pharmacy, 129 N Second St, Cochran, GA ...
# gmap_id                         0x88f16e41928ff687:0x883dad4fd048e8f8
# description                                                      None
# latitude                                                      32.3883
# longitude                                                    -83.3571
# category                                                   [Pharmacy]
# avg_rating                                                        4.9
# num_of_reviews                                                     16
# price                                                            None
# hours               [[Friday, 8AM–6PM], [Saturday, 8AM–12PM], [Sun...
# MISC                {'Service options': ['In-store shopping', 'Sam...
# state                                               Open ⋅ Closes 6PM
# relative_results    [0x88f16e41929435cf:0x5b2532a2885e9ef6, 0x88f1...
# url                 https://www.google.com/maps/place//data=!4m2!3...
# Name: 0, dtype: object

# %%
df_metadata_5 = pd.read_json('/content/drive/MyDrive/google_maps/metadata_sitios/Copia de 5.json', lines=True)
df_metadata_5.iloc[0]

# %%
df_metadata_11 = pd.read_json('/content/drive/MyDrive/google_maps/metadata_sitios/Copia de 11.json', lines=True)
df_metadata_11.iloc[0]

# %% [markdown]
# ### Las keys son similares en todos los json files, ahora intentamos juntar todos los archivos .json en un solo DataFrame.

# %%
file_path1 = '/content/drive/MyDrive/google_maps/metadata_sitios/Copia de 1.json'
df1 = pd.read_json(file_path1, lines=True)

file_path2 = '/content/drive/MyDrive/google_maps/metadata_sitios/Copia de 2.json'
df2 = pd.read_json(file_path2, lines=True)

file_path3 = '/content/drive/MyDrive/google_maps/metadata_sitios/Copia de 3.json'
df3 = pd.read_json(file_path3, lines=True)

file_path4 = '/content/drive/MyDrive/google_maps/metadata_sitios/Copia de 4.json'
df4 = pd.read_json(file_path4, lines=True)

file_path5 = '/content/drive/MyDrive/google_maps/metadata_sitios/Copia de 5.json'
df5 = pd.read_json(file_path5, lines=True)

file_path6 = '/content/drive/MyDrive/google_maps/metadata_sitios/Copia de 6.json'
df6 = pd.read_json(file_path6, lines=True)

'''
file_path7 = '/content/drive/MyDrive/google_maps/metadata_sitios/Copia de 7.json'
df7 = pd.read_json(file_path7, lines=True)

file_path8 = '/content/drive/MyDrive/google_maps/metadata_sitios/Copia de 8.json'
df8 = pd.read_json(file_path8, lines=True)

file_path9 = '/content/drive/MyDrive/google_maps/metadata_sitios/Copia de 9.json'
df9 = pd.read_json(file_path9, lines=True)

file_path10 = '/content/drive/MyDrive/google_maps/metadata_sitios/Copia de 10.json'
df10 = pd.read_json(file_path10, lines=True)

file_path11 = '/content/drive/MyDrive/google_maps/metadata_sitios/Copia de 11.json'
df11 = pd.read_json(file_path11, lines=True)
'''

# %%
df_list1 = [df1, df2, df3, df4, df5, df6] #df7, df8, df9, df10, df11]
df_metadata_sitios_google1 = pd.concat(df_list1, ignore_index=True)
df_metadata_sitios_google1.to_csv('/content/drive/MyDrive/Otros/df_metadata_sitios_google1.csv', index=False)

# %%
file_path7 = '/content/drive/MyDrive/google_maps/metadata_sitios/Copia de 7.json'
df7 = pd.read_json(file_path7, lines=True)

file_path8 = '/content/drive/MyDrive/google_maps/metadata_sitios/Copia de 8.json'
df8 = pd.read_json(file_path8, lines=True)

file_path9 = '/content/drive/MyDrive/google_maps/metadata_sitios/Copia de 9.json'
df9 = pd.read_json(file_path9, lines=True)

file_path10 = '/content/drive/MyDrive/google_maps/metadata_sitios/Copia de 10.json'
df10 = pd.read_json(file_path10, lines=True)

file_path11 = '/content/drive/MyDrive/google_maps/metadata_sitios/Copia de 11.json'
df11 = pd.read_json(file_path11, lines=True)

# %%
df_list2 = [df7, df8, df9, df10, df11]
df_metadata_sitios_google2 = pd.concat(df_list2, ignore_index=True)
df_metadata_sitios_google2.to_csv('/content/drive/MyDrive/Otros/df_metadata_sitios_google2.csv', index=False)

# %% [markdown]
# ### Unificamos los csv de los archivos guardados.

# %%
df_1_metadata = pd.read_csv('/content/drive/MyDrive/Otros/df_metadata_sitios_google1.csv')

# %%
df_2_metadata = pd.read_csv('/content/drive/MyDrive/Otros/df_metadata_sitios_google2.csv')

# %%
df_list_final = [df_1_metadata,df_2_metadata]
df_metada = pd.concat(df_list_final, ignore_index=True)

# %%
df_metada = df_metada.drop(columns=['relative_results','url'])

# %%
df_metada = df_metada.drop_duplicates()

# %% [markdown]
# ### Guardamos el archivo csv unificado.

# %%
df_metada.to_csv('/content/drive/MyDrive/Otros/googlemaps_metadata_sitios.csv', index=False)

# %% [markdown]
# ###  Cargamos el csv unificado y filtramos para Florida usando la columna address.

# %%
import pandas as pd

df_metada = pd.read_csv('/content/drive/MyDrive/Otros/googlemaps_metadata_sitios.csv')

# %%
df_metada.iloc[105]
# Out:
# name                                              Brian Shaheen, MD
# address           Brian Shaheen, MD, 2421 Thomas Dr, Panama City...
# gmap_id                       0x8893863ea87bd5dd:0x9383ebf973e74abb
# description                                                     NaN
# latitude                                                  30.159982
# longitude                                                -85.752277
# category          ['Family practice physician', 'General practit...
# avg_rating                                                      4.2
# num_of_reviews                                                   18
# price                                                           NaN
# hours             [['Thursday', '8AM–5PM'], ['Friday', '8AM–5PM'...
# MISC              {'Service options': ['Online care'], 'Accessib...
# state                                             Open ⋅ Closes 5PM
# Name: 105, dtype: object

# %% [markdown]
# ### Extraeremos datos de la columna:
#
#  - Address
#
# ### Desanidaremos las columnas:
#
#  - Category
#
#  - MISC
#
#  - Hours

# %% [markdown]
# ## 2. Columna Address

# %% [markdown]
# #### Filtramos para Florida

# %%
print(df_metada.iloc[14]['address'])
print(type(df_metada.iloc[14]['address']))
# Out:
# NTK OUTDOOR, 2315 NW 107th Ave #1B18, Miami, FL 33172
# <class 'str'>

# %%
metdat_florida = df_metada[df_metada['address'].str.contains('FL', na=False, case=True)]
metdat_florida = metdat_florida.copy()
metdat_florida.head(3)
# Out:
#                              name  \
# 14                    NTK OUTDOOR
# 45  Cruises Inc. - Connie Stewart
# 56     Seminole Family Restaurant
#
#                                               address  \
# 14  NTK OUTDOOR, 2315 NW 107th Ave #1B18, Miami, F...
# 45  Cruises Inc. - Connie Stewart, 6602 52nd Ln, P...
# 56  Seminole Family Restaurant, 6864 Seminole Blvd...
#
#                                   gmap_id description   latitude  longitude  \
# 14   0x88d9beb4fe0532c1:0xef0555c169299d6         NaN  25.795204 -80.366038
# 45  0x88c2e49b79f06c31:0x4ed8c8ce27e926e0         NaN  27.832187 -82.704805
# 56  0x88c2fb8614e57ce9:0x40b51628875ad6e9         NaN  27.834885 -82.787419
#
#                 category  avg_rating  num_of_reviews price  \
# 14  ['Corporate office']         5.0              35   NaN
# 45     ['Cruise agency']         5.0               2   NaN
# 56                   NaN         3.6               8    $$
#
#                                                 hours  \
# 14  [['Thursday', '9AM–6PM'], ['Friday', '9AM–6PM'...
# 45  [['Thursday', '9AM–5PM'], ['Friday', '9AM–5PM'...
# 56                                                NaN
#
#                                                  MISC              state
# 14  {'Accessibility': ['Wheelchair accessible entr...  Open ⋅ Closes 6PM
# 45                                                NaN  Open ⋅ Closes 5PM
# 56                                                NaN                NaN

# %% [markdown]
# ### Extraemos ciudad(city), stado (states) y codigo postal (postal_code)

# %%
regex = r'.+,\s*(?P<city>[^,]+),\s*(?P<states>[^\s]+)\s+(?P<postal_code>\S+)'
new_df = metdat_florida['address'].str.extract(regex)

metdat_florida = metdat_florida.join(new_df,lsuffix='_original', rsuffix='_new')

metdat_florida.head(3)
# Out:
#                              name  \
# 14                    NTK OUTDOOR
# 45  Cruises Inc. - Connie Stewart
# 56     Seminole Family Restaurant
#
#                                               address  \
# 14  NTK OUTDOOR, 2315 NW 107th Ave #1B18, Miami, F...
# 45  Cruises Inc. - Connie Stewart, 6602 52nd Ln, P...
# 56  Seminole Family Restaurant, 6864 Seminole Blvd...
#
#                                   gmap_id description   latitude  longitude  \
# 14   0x88d9beb4fe0532c1:0xef0555c169299d6         NaN  25.795204 -80.366038
# 45  0x88c2e49b79f06c31:0x4ed8c8ce27e926e0         NaN  27.832187 -82.704805
# 56  0x88c2fb8614e57ce9:0x40b51628875ad6e9         NaN  27.834885 -82.787419
#
#                 category  avg_rating  num_of_reviews price  \
# 14  ['Corporate office']         5.0              35   NaN
# 45     ['Cruise agency']         5.0               2   NaN
# 56                   NaN         3.6               8    $$
#
#                                                 hours  \
# 14  [['Thursday', '9AM–6PM'], ['Friday', '9AM–6PM'...
# 45  [['Thursday', '9AM–5PM'], ['Friday', '9AM–5PM'...
# 56                                                NaN
#
#                                                  MISC              state  \
# 14  {'Accessibility': ['Wheelchair accessible entr...  Open ⋅ Closes 6PM
# 45                                                NaN  Open ⋅ Closes 5PM
# 56                                                NaN                NaN
#
#              city states postal_code
# 14          Miami     FL       33172
# 45  Pinellas Park     FL       33781
# 56       Seminole     FL       33772

# %%
# FILTRO POR CODIGO POSTAL

metdat_florida['postal_code'] = pd.to_numeric(metdat_florida['postal_code'], errors='coerce') # metdat_florida

metdat_florida = metdat_florida[(metdat_florida['postal_code'] >= 32003) & (metdat_florida['postal_code'] <= 34997)].copy()
# According to website https://www.zipcode.com.ng/2022/06/list-of-florida-zip-codes-.html

# %%
# FILTRO POR CIUDADES FLORIDA

df_florida_cities = pd.read_json('/content/drive/MyDrive/Otros/us-cities-table-for-florida.json')
# Fuente Json https://worldpopulationreview.com/states/cities/florida

florida_names_list = df_florida_cities['name'].tolist()

metdat_florida = metdat_florida[metdat_florida['city'].isin(florida_names_list)]
metdat_florida.head(3)
# Out:
#                              name  \
# 14                    NTK OUTDOOR
# 45  Cruises Inc. - Connie Stewart
# 56     Seminole Family Restaurant
#
#                                               address  \
# 14  NTK OUTDOOR, 2315 NW 107th Ave #1B18, Miami, F...
# 45  Cruises Inc. - Connie Stewart, 6602 52nd Ln, P...
# 56  Seminole Family Restaurant, 6864 Seminole Blvd...
#
#                                   gmap_id description   latitude  longitude  \
# 14   0x88d9beb4fe0532c1:0xef0555c169299d6         NaN  25.795204 -80.366038
# 45  0x88c2e49b79f06c31:0x4ed8c8ce27e926e0         NaN  27.832187 -82.704805
# 56  0x88c2fb8614e57ce9:0x40b51628875ad6e9         NaN  27.834885 -82.787419
#
#                 category  avg_rating  num_of_reviews price  \
# 14  ['Corporate office']         5.0              35   NaN
# 45     ['Cruise agency']         5.0               2   NaN
# 56                   NaN         3.6               8    $$
#
#                                                 hours  \
# 14  [['Thursday', '9AM–6PM'], ['Friday', '9AM–6PM'...
# 45  [['Thursday', '9AM–5PM'], ['Friday', '9AM–5PM'...
# 56                                                NaN
#
#                                                  MISC              state  \
# 14  {'Accessibility': ['Wheelchair accessible entr...  Open ⋅ Closes 6PM
# 45                                                NaN  Open ⋅ Closes 5PM
# 56                                                NaN                NaN
#
#              city states  postal_code
# 14          Miami     FL      33172.0
# 45  Pinellas Park     FL      33781.0
# 56       Seminole     FL      33772.0

# %% [markdown]
# ## 3. Columna Category

# %%
# Le damos el formato adecuado a la columna category:

import numpy as np
import ast

metdat_florida['category'] = metdat_florida['category'].apply(lambda x: ast.literal_eval(x)
                                                                if isinstance(x, str) else np.nan)

def format_category_list(category_list):
    if isinstance(category_list, list):
        return ', '.join(category_list)
    else:
        return category_list

metdat_florida['category'] = metdat_florida['category'].apply(format_category_list)
metdat_florida.head(3)
# Out:
#                              name  \
# 14                    NTK OUTDOOR
# 45  Cruises Inc. - Connie Stewart
# 56     Seminole Family Restaurant
#
#                                               address  \
# 14  NTK OUTDOOR, 2315 NW 107th Ave #1B18, Miami, F...
# 45  Cruises Inc. - Connie Stewart, 6602 52nd Ln, P...
# 56  Seminole Family Restaurant, 6864 Seminole Blvd...
#
#                                   gmap_id description   latitude  longitude  \
# 14   0x88d9beb4fe0532c1:0xef0555c169299d6         NaN  25.795204 -80.366038
# 45  0x88c2e49b79f06c31:0x4ed8c8ce27e926e0         NaN  27.832187 -82.704805
# 56  0x88c2fb8614e57ce9:0x40b51628875ad6e9         NaN  27.834885 -82.787419
#
#             category  avg_rating  num_of_reviews price  \
# 14  Corporate office         5.0              35   NaN
# 45     Cruise agency         5.0               2   NaN
# 56               NaN         3.6               8    $$
#
#                                                 hours  \
# 14  [['Thursday', '9AM–6PM'], ['Friday', '9AM–6PM'...
# 45  [['Thursday', '9AM–5PM'], ['Friday', '9AM–5PM'...
# 56                                                NaN
#
#                                                  MISC              state  \
# 14  {'Accessibility': ['Wheelchair accessible entr...  Open ⋅ Closes 6PM
# 45                                                NaN  Open ⋅ Closes 5PM
# 56                                                NaN                NaN
#
#              city states  postal_code
# 14          Miami     FL      33172.0
# 45  Pinellas Park     FL      33781.0
# 56       Seminole     FL      33772.0

# %%
metdat_florida['category'].value_counts().sum()
# Out:
# 186693

# %%
business_list = ['Restaurant']

metdat_florida = metdat_florida[metdat_florida['category'].isin(business_list)]
metdat_florida.head(3)
# Out:
#                     name                                            address  \
# 114   Cape Seafood Shack  Cape Seafood Shack, 603 Del Prado Blvd S, Cape...
# 674              Hot Box      Hot Box, 1-99 Kinkaid St, Pensacola, FL 32507
# 2438        Bachata Rosa    Bachata Rosa, 887w W 29th St, Hialeah, FL 33012
#
#                                     gmap_id description   latitude  longitude  \
# 114   0x88db4147b1d9e6f3:0x943dbd10a92ba1b1         NaN  26.641377 -81.940545
# 674   0x8890b9241e704667:0x3a1e565c17c00993         NaN  30.391411 -87.267220
# 2438  0x88d9ba5d65937567:0xbc27649cf513cc89         NaN  25.848173 -80.299773
#
#         category  avg_rating  num_of_reviews price  \
# 114   Restaurant         5.0               1    $$
# 674   Restaurant         4.2               5   NaN
# 2438  Restaurant         3.6               8   NaN
#
#                                                   hours  \
# 114                                                 NaN
# 674   [['Thursday', '6:30AM–6PM'], ['Friday', '6:30A...
# 2438  [['Thursday', '6PM–1AM'], ['Friday', '6PM–1AM'...
#
#                                                    MISC               state  \
# 114   {'Service options': ['Dine-in', 'Delivery'], '...                 NaN
# 674                   {'Service options': ['Delivery']}  Permanently closed
# 2438  {'Service options': ['Dine-in', 'Delivery'], '...  Closed ⋅ Opens 6PM
#
#             city states  postal_code
# 114   Cape Coral     FL      33990.0
# 674    Pensacola     FL      32507.0
# 2438     Hialeah     FL      33012.0

# %%
# Realizamos un conteo del top 10 de categorias:

category = metdat_florida['category'].str.split(', ').explode()
category_counts = category.value_counts()/len(metdat_florida)

# Mostrar el conteo de 24 categorías mas importantes
category_counts.head(24)
# Out:
# Restaurant    1.0
# Name: category, dtype: float64

# %%
top_category_names = category_counts.head(24).index.tolist()
top_category_names
# Out:
# ['Restaurant']

# %% [markdown]
# ## 4. Columna MISC

# %%
print(metdat_florida.iloc[3]['MISC'])
print(type(metdat_florida.iloc[3]['MISC']))
# Out:
# {'Service options': ['Outdoor seating', 'Takeout', 'Delivery'], 'Highlights': ['Live music'], 'Offerings': ['Beer', 'Happy hour drinks', 'Happy hour food', 'Small plates', 'Wine'], 'Dining options': ['Breakfast', 'Lunch', 'Dinner', 'Seating'], 'Crowd': ['Family-friendly'], 'Payments': ['Cash-only', 'Debit cards', 'Credit cards']}
# <class 'str'>

# %%
print(metdat_florida.iloc[12]['MISC'])
print(type(metdat_florida.iloc[12]['MISC']))
# Out:
# {'Service options': ['Takeout', 'Dine-in', 'Delivery'], 'Popular for': ['Lunch'], 'Accessibility': ['Wheelchair accessible entrance'], 'Offerings': ['Healthy options', 'Quick bite'], 'Atmosphere': ['Casual']}
# <class 'str'>

# %% [markdown]
# ## Lista de miscelaneos
#
# 'Service options': ['Takeout', 'Dine-in', 'Delivery']
#
# 'Highlights': ['Live music']
#
# 'Popular for': ['Lunch']
#
# 'Accessibility': ['Wheelchair accessible entrance']
#
# 'Offerings': ['Healthy options', 'Quick bite']
#
# 'Dining options': ['Breakfast', 'Lunch', 'Dinner', 'Seating']
#
# 'Crowd': ['Family-friendly']
#
# 'Atmosphere': ['Casual']
#
# 'Payments': ['Checks', 'Debit cards', 'NFC mobile payments', 'Credit cards']
#
# 'Amenities': ['Public restroom']
#
# 'Service options': ['No-contact delivery', 'Delivery', 'In-store shopping', 'Same-day delivery']
#
# 'Planning': ['Quick visit']

# %%
metdat_florida['MISC'] = metdat_florida['MISC'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else np.nan)

desired_keys = ['Service options','Highlights','Popular for','Accessibility','Offerings','Dining options','Crowd','Atmosphere','Payments','Amenities','Service options','Planning']

def extract_key_values(misc_dict, key):
    if isinstance(misc_dict, dict) and key in misc_dict:
        return ', '.join(misc_dict[key])
    else:
        return np.nan

# creamos columnas por cada key
for key in desired_keys:
    metdat_florida[key] = metdat_florida['MISC'].apply(lambda x: extract_key_values(x, key))

# Drop the 'MISC'
metdat_florida = metdat_florida.drop(columns=['MISC'])

metdat_florida
# Out:
#                                     name  \
# 114                   Cape Seafood Shack
# 674                              Hot Box
# 2438                        Bachata Rosa
# 3258                   Zampini's Bottega
# 3449                        Choices Cafe
# ...                                  ...
# 2992530  Me Hungry Vegetarian Restaurant
# 2993203               Grain & Berry Cafe
# 2993233     The Club at Key West Harbour
# 2996034       Daniel's Cheesesteak House
# 2998098     Bakery Antojitos Colombianos
#
#                                                    address  \
# 114      Cape Seafood Shack, 603 Del Prado Blvd S, Cape...
# 674          Hot Box, 1-99 Kinkaid St, Pensacola, FL 32507
# 2438       Bachata Rosa, 887w W 29th St, Hialeah, FL 33012
# 3258     Zampini's Bottega, 510 SE 5th Ave, Fort Lauder...
# 3449        Choices Cafe, 711 NW 27th Ave, Miami, FL 33125
# ...                                                    ...
# 2992530  Me Hungry Vegetarian Restaurant, 105 N State R...
# 2993203  Grain & Berry Cafe, 2722 N Roosevelt Blvd, Key...
# 2993233  The Club at Key West Harbour, 6000 Peninsular ...
# 2996034  Daniel's Cheesesteak House, 978 E Plant St, Wi...
# 2998098  Bakery Antojitos Colombianos, 12161 SW 152nd S...
#
#                                        gmap_id  \
# 114      0x88db4147b1d9e6f3:0x943dbd10a92ba1b1
# 674      0x8890b9241e704667:0x3a1e565c17c00993
# 2438     0x88d9ba5d65937567:0xbc27649cf513cc89
# 3258      0x88d900575f0dd065:0x9b3638d2a80be4d
# 3449     0x88d9b719170a9f61:0x30d454a980f76ad3
# ...                                        ...
# 2992530  0x88d90724bd1aaaa9:0xcddf8a58b3167313
# 2993203  0x88d1b1952d3820b7:0x3cb6313204ef404f
# 2993233  0x88d1b19a291afb27:0xc996708404476f68
# 2996034  0x88e783dedf1bcaeb:0xba9e5f8779cf4591
# 2998098  0x88d9c3c682fe8a01:0x34f123db79ec201e
#
#                                                description   latitude  \
# 114                                                    NaN  26.641377
# 674                                                    NaN  30.391411
# 2438                                                   NaN  25.848173
# 3258                                                   NaN  26.116549
# 3449     Quaint cafe with a changing daily menu focused...  25.779837
# ...                                                    ...        ...
# 2992530                                                NaN  26.121813
# 2993203                                                NaN  24.564509
# 2993233                                                NaN  24.564275
# 2996034                                                NaN  28.568100
# 2998098                                                NaN  25.627098
#
#          longitude    category  avg_rating  num_of_reviews price  ...  \
# 114     -81.940545  Restaurant         5.0               1    $$  ...
# 674     -87.267220  Restaurant         4.2               5   NaN  ...
# 2438    -80.299773  Restaurant         3.6               8   NaN  ...
# 3258    -80.138561  Restaurant         4.7              18   NaN  ...
# 3449    -80.239103  Restaurant         4.6              45     $  ...
# ...            ...         ...         ...             ...   ...  ...
# 2992530 -80.202066  Restaurant         4.4             118    $$  ...
# 2993203 -81.772586  Restaurant         4.3             106    $$  ...
# 2993233 -81.726255  Restaurant         3.9               7   NaN  ...
# 2996034 -81.572432  Restaurant         4.7             288     $  ...
# 2998098 -80.389759  Restaurant         4.5              46   NaN  ...
#
#            Highlights                    Popular for  \
# 114               NaN                            NaN
# 674               NaN                            NaN
# 2438              NaN             Lunch, Solo dining
# 3258       Live music                            NaN
# 3449              NaN                            NaN
# ...               ...                            ...
# 2992530           NaN     Lunch, Dinner, Solo dining
# 2993203  Great coffee  Breakfast, Lunch, Solo dining
# 2993233           NaN                            NaN
# 2996034           NaN     Lunch, Dinner, Solo dining
# 2998098           NaN                            NaN
#
#                                              Accessibility  \
# 114      Wheelchair accessible entrance, Wheelchair acc...
# 674                                                    NaN
# 2438                        Wheelchair accessible entrance
# 3258                                                   NaN
# 3449                                                   NaN
# ...                                                    ...
# 2992530                     Wheelchair accessible entrance
# 2993203                     Wheelchair accessible entrance
# 2993233                     Wheelchair accessible entrance
# 2996034                     Wheelchair accessible entrance
# 2998098                                                NaN
#
#                                                  Offerings  \
# 114                                           Comfort food
# 674                                                    NaN
# 2438                                                   NaN
# 3258     Beer, Happy hour drinks, Happy hour food, Smal...
# 3449                                                   NaN
# ...                                                    ...
# 2992530  Comfort food, Healthy options, Quick bite, Sma...
# 2993203  Coffee, Healthy options, Quick bite, Vegetaria...
# 2993233  Alcohol, Beer, Coffee, Happy hour drinks, Happ...
# 2996034                   Coffee, Comfort food, Quick bite
# 2998098                                                NaN
#
#                             Dining options             Crowd    Atmosphere  \
# 114                          Lunch, Dinner               NaN        Casual
# 674                                    NaN               NaN           NaN
# 2438                                   NaN            Groups        Casual
# 3258     Breakfast, Lunch, Dinner, Seating   Family-friendly           NaN
# 3449                                   NaN               NaN           NaN
# ...                                    ...               ...           ...
# 2992530                            Dessert  Groups, Tourists  Casual, Cozy
# 2993203                            Dessert          Tourists  Casual, Cozy
# 2993233             Lunch, Dinner, Dessert   Family-friendly           NaN
# 2996034                                NaN            Groups        Casual
# 2998098                                NaN               NaN           NaN
#
#                                      Payments             Amenities  \
# 114                                       NaN         Good for kids
# 674                                       NaN                   NaN
# 2438                                      NaN                   NaN
# 3258     Cash-only, Debit cards, Credit cards                   NaN
# 3449                                      NaN         Good for kids
# ...                                       ...                   ...
# 2992530                                   NaN         Good for kids
# 2993203                                   NaN         Good for kids
# 2993233                                   NaN  Bar onsite, Restroom
# 2996034                   NFC mobile payments         Good for kids
# 2998098                                   NaN         Good for kids
#
#                      Planning
# 114                       NaN
# 674                       NaN
# 2438                      NaN
# 3258                      NaN
# 3449                      NaN
# ...                       ...
# 2992530                   NaN
# 2993203                   NaN
# 2993233  Accepts reservations
# 2996034                   NaN
# 2998098                   NaN
#
# [2554 rows x 26 columns]

# %%
columns_to_iterate = ['Service options','Highlights','Popular for','Accessibility','Offerings','Dining options','Crowd','Atmosphere','Payments','Amenities','Service options','Planning']

for col in columns_to_iterate:
    value_counts = metdat_florida[col].value_counts()
    total_count = value_counts.sum()  # Calculate the sum of counts
    print(f"Value Counts for {col}:\n{value_counts}\nTotal Count: {total_count}\n")
# Out:
# Value Counts for Service options:
# Delivery                                                                             693
# Takeout, Delivery                                                                    330
# Takeout, Dine-in, Delivery                                                           296
# Delivery, Takeout, Dine-in                                                           212
# Delivery, Takeout                                                                    130
#                                                                                     ...
# Curbside pickup, Takeout, Delivery                                                     1
# Outdoor seating, Curbside pickup, No-contact delivery, Takeout, Delivery, Dine-in      1
# Curbside pickup, Delivery, Drive-through, Takeout                                      1
# Curbside pickup, No-contact delivery, Drive-through, Takeout, Delivery, Dine-in        1
# Outdoor seating, Curbside pickup, Takeout, Delivery                                    1
# Name: Service options, Length: 73, dtype: int64
# Total Count: 2531
#
# Value Counts for Highlights:
# Great coffee                                                               156
# Great dessert                                                               69
# Great beer selection, Great cocktails                                       43
# Great beer selection                                                        40
# LGBTQ friendly, Transgender safespace                                       35
#                                                                           ...
# Fast service, Great cocktails, Live music                                    1
# Great beer selection, Great cocktails, Great wine list, Live music           1
# Great cocktails, Live music, Rooftop seating                                 1
# Great beer selection, LGBTQ friendly, Live music, Transgender safespace      1
# Great cocktails, LGBTQ friendly, Rooftop seating                             1
# Name: Highlights, Length: 133, dtype: int64
# Total Count: 709
#
# Value Counts for Popular for:
# Lunch, Dinner, Solo dining               748
# Lunch, Solo dining                       199
# Solo dining                              192
# Dinner, Solo dining                      146
# Breakfast, Lunch, Solo dining            114
# Breakfast, Lunch, Dinner, Solo dining     79
# Lunch, Dinner                             65
# Lunch                                     22
# Dinner                                    22
# Breakfast, Solo dining                    12
# Breakfast, Lunch                           8
# Breakfast                                  5
# Breakfast, Lunch, Dinner                   4
# Breakfast, Dinner, Solo dining             2
# Name: Popular for, dtype: int64
# Total Count: 1618
#
# Value Counts for Accessibility:
# Wheelchair accessible entrance                                                                                                                                      1339
# Wheelchair accessible entrance, Wheelchair accessible parking lot, Wheelchair accessible seating                                                                     127
# Wheelchair accessible entrance, Wheelchair accessible parking lot, Wheelchair accessible restroom, Wheelchair accessible seating                                     118
# Wheelchair accessible entrance, Wheelchair accessible seating                                                                                                         53
# Wheelchair accessible entrance, Wheelchair accessible parking lot                                                                                                     45
# Wheelchair accessible entrance, Wheelchair accessible restroom                                                                                                        34
# Wheelchair accessible entrance, Wheelchair accessible restroom, Wheelchair accessible seating                                                                         28
# Wheelchair accessible elevator, Wheelchair accessible entrance, Wheelchair accessible parking lot, Wheelchair accessible restroom, Wheelchair accessible seating      24
# Wheelchair accessible entrance, Wheelchair accessible parking lot, Wheelchair accessible restroom                                                                     20
# Wheelchair accessible seating                                                                                                                                         15
# Wheelchair accessible parking lot                                                                                                                                     12
# Wheelchair accessible parking lot, Wheelchair accessible seating                                                                                                      11
# Wheelchair accessible restroom                                                                                                                                         3
# Wheelchair accessible parking lot, Wheelchair accessible restroom, Wheelchair accessible seating                                                                       3
# Wheelchair accessible elevator, Wheelchair accessible entrance, Wheelchair accessible parking lot                                                                      2
# Wheelchair accessible elevator, Wheelchair accessible entrance                                                                                                         2
# Wheelchair accessible elevator, Wheelchair accessible entrance, Wheelchair accessible restroom, Wheelchair accessible seating                                          2
# Wheelchair accessible restroom, Wheelchair accessible seating                                                                                                          1
# Wheelchair accessible elevator                                                                                                                                         1
# Wheelchair accessible entrance, Wheelchair accessible parking lot, Wheelchair accessible seating, Wheelchair accessible restroom                                       1
# Wheelchair accessible elevator, Wheelchair accessible entrance, Wheelchair accessible parking lot, Wheelchair accessible restroom                                      1
# Wheelchair accessible elevator, Wheelchair accessible entrance, Wheelchair accessible parking lot, Wheelchair accessible seating                                       1
# Wheelchair accessible restroom, Wheelchair accessible entrance                                                                                                         1
# Wheelchair accessible parking lot, Wheelchair accessible restroom                                                                                                      1
# Name: Accessibility, dtype: int64
# Total Count: 1845
#
# Value Counts for Offerings:
# Comfort food, Quick bite                                                                                        291
# Comfort food, Quick bite, Small plates                                                                          215
# Comfort food                                                                                                    103
# Coffee, Comfort food, Quick bite                                                                                 77
# Coffee, Comfort food, Quick bite, Small plates                                                                   74
#                                                                                                                ...
# Beer, Coffee, Comfort food, Happy hour food, Small plates, Wine                                                   1
# Kids' menu, Small plates, Vegetarian options, Wine                                                                1
# Alcohol, Beer, Cocktails, Coffee, Happy hour drinks, Happy hour food, Hard liquor, Late-night food, Wine          1
# Alcohol, Beer, Coffee, Happy hour drinks, Happy hour food, Hard liquor, Kids' menu, Vegetarian options, Wine      1
# Alcohol, Beer, Coffee, Happy hour drinks, Happy hour food, Hard liquor, Small plates, Wine                        1
# Name: Offerings, Length: 560, dtype: int64
# Total Count: 1995
#
# Value Counts for Dining options:
# Dessert                                                 594
# Lunch, Dinner                                           172
# Lunch, Dinner, Catering, Dessert, Seating                89
# Breakfast, Lunch, Dinner, Catering, Dessert, Seating     63
# Lunch, Dinner, Dessert                                   61
# Lunch, Dinner, Dessert, Seating                          54
# Breakfast, Lunch                                         27
# Lunch, Dinner, Catering, Dessert                         26
# Dinner, Dessert, Seating                                 25
# Lunch                                                    24
# Dinner                                                   22
# Breakfast, Lunch, Dinner, Dessert                        21
# Breakfast, Lunch, Dinner, Dessert, Seating               21
# Breakfast, Lunch, Dinner                                 20
# Lunch, Dinner, Seating                                   19
# Lunch, Dinner, Catering, Seating                         18
# Dinner, Dessert                                          15
# Breakfast, Lunch, Catering, Dessert, Seating             14
# Breakfast, Lunch, Dessert, Seating                       12
# Dinner, Catering, Dessert, Seating                        9
# Catering, Dessert                                         9
# Lunch, Dinner, Catering                                   9
# Breakfast, Lunch, Dessert                                 9
# Breakfast, Lunch, Dinner, Catering, Dessert               7
# Catering                                                  6
# Breakfast                                                 6
# Lunch, Dessert                                            5
# Breakfast, Lunch, Catering, Dessert                       5
# Lunch, Catering, Dessert, Seating                         5
# Breakfast, Lunch, Seating                                 5
# Lunch, Catering, Seating                                  5
# Breakfast, Lunch, Dinner, Catering, Seating               5
# Dessert, Seating                                          5
# Dinner, Catering, Dessert                                 4
# Lunch, Seating                                            4
# Seating                                                   4
# Lunch, Catering, Dessert                                  4
# Breakfast, Lunch, Catering, Seating                       3
# Breakfast, Lunch, Dinner, Catering                        2
# Breakfast, Lunch, Dinner, Seating                         2
# Breakfast, Dinner, Dessert, Seating                       2
# Lunch, Dessert, Seating                                   2
# Breakfast, Lunch, Catering                                1
# Lunch, Catering, Counter service                          1
# Dinner, Seating                                           1
# Breakfast, Dessert, Seating                               1
# Lunch, Catering                                           1
# Catering, Dessert, Seating                                1
# Catering, Seating                                         1
# Dinner, Catering, Seating                                 1
# Breakfast, Catering, Dessert                              1
# Lunch, Dinner, Counter service, Dessert                   1
# Breakfast, Catering, Dessert, Seating                     1
# Dinner, Catering                                          1
# Name: Dining options, dtype: int64
# Total Count: 1426
#
# Value Counts for Crowd:
# Groups                                                 511
# Groups, Tourists                                       321
# Family-friendly                                        157
# Tourists                                               113
# Family-friendly, Groups, Tourists                      104
# Family-friendly, Groups                                 87
# Groups, Locals                                          33
# Locals                                                  32
# Family-friendly, Tourists                               26
# College students, Groups, Tourists                      25
# College students, Groups                                17
# Groups, Locals, Tourists                                15
# College students, Family-friendly, Groups, Tourists     14
# College students, Tourists                              12
# College students                                         7
# College students, Family-friendly                        5
# College students, Family-friendly, Groups                4
# College students, Groups, Locals                         4
# College students, Family-friendly, Tourists              4
# Name: Crowd, dtype: int64
# Total Count: 1491
#
# Value Counts for Atmosphere:
# Casual                                       1099
# Casual, Cozy                                  699
# Casual, Quiet                                  18
# Cozy                                           15
# Casual, Cozy, Quiet                            10
# Cozy, Romantic                                  6
# Casual, Cozy, Romantic                          5
# Casual, Cozy, Trending                          4
# Casual, Cozy, Romantic, Upscale                 4
# Casual, Cozy, Historic, Romantic                3
# Cozy, Romantic, Upscale                         3
# Trending                                        3
# Historic                                        2
# Casual, Trending                                2
# Cozy, Historic, Romantic, Upscale               1
# Casual, Romantic                                1
# Casual, Cozy, Quiet, Romantic, Upscale          1
# Casual, Historic                                1
# Casual, Cozy, Quiet, Romantic                   1
# Casual, Cozy, Historic                          1
# Casual, Cozy, Historic, Romantic, Upscale       1
# Name: Atmosphere, dtype: int64
# Total Count: 1880
#
# Value Counts for Payments:
# Debit cards, Credit cards                                    159
# NFC mobile payments                                          146
# Debit cards                                                  142
# Debit cards, NFC mobile payments, Credit cards                93
# Debit cards, NFC mobile payments                              33
# Credit cards                                                  28
# NFC mobile payments, Credit cards                              9
# Cash-only, Debit cards, Credit cards                           8
# Checks, Debit cards, NFC mobile payments, Credit cards         7
# Checks, Debit cards, Credit cards                              7
# Cash-only, Debit cards                                         6
# Cash-only                                                      6
# Checks, Debit cards                                            3
# Checks                                                         2
# Cash-only, Debit cards, NFC mobile payments, Credit cards      2
# Checks, Debit cards, NFC mobile payments                       2
# Cash-only, Credit cards                                        1
# Cash-only, Checks, Debit cards, Credit cards                   1
# Name: Payments, dtype: int64
# Total Count: 655
#
# Value Counts for Amenities:
# Good for kids                                                                       1223
# Bar onsite                                                                           170
# Bar onsite, Good for kids                                                             90
# Good for kids, High chairs                                                            67
# Good for kids, Restroom                                                               63
# Bar onsite, Good for kids, High chairs                                                57
# Bar onsite, Good for kids, High chairs, Restroom, Wi-Fi                               56
# Good for kids, High chairs, Restroom, Wi-Fi                                           46
# Good for kids, High chairs, Restroom                                                  40
# Bar onsite, Good for kids, High chairs, Restroom                                      32
# Bar onsite, High chairs                                                               31
# Good for kids, Wi-Fi                                                                  23
# Good for kids, Restroom, Wi-Fi                                                        22
# Restroom                                                                              19
# Bar onsite, Restroom                                                                  15
# Bar onsite, Good for kids, Restroom, Wi-Fi                                            13
# Bar onsite, Restroom, Wi-Fi                                                           11
# Bar onsite, Good for kids, Restroom                                                   11
# Gender-neutral restroom, Good for kids, High chairs, Restroom, Wi-Fi                  11
# Bar onsite, High chairs, Restroom, Wi-Fi                                              11
# Bar onsite, High chairs, Restroom                                                      9
# Bar onsite, Wi-Fi                                                                      9
# Good for kids, High chairs, Wi-Fi                                                      7
# Bar onsite, Gender-neutral restroom, Good for kids, High chairs, Restroom, Wi-Fi       6
# Bar onsite, Good for kids, High chairs, Wi-Fi                                          6
# High chairs, Restroom                                                                  6
# Gender-neutral restroom, Good for kids, High chairs, Restroom                          6
# Wi-Fi                                                                                  6
# Bar onsite, High chairs, Wi-Fi                                                         5
# High chairs                                                                            5
# Gender-neutral restroom, Good for kids                                                 4
# Gender-neutral restroom, Good for kids, Restroom                                       3
# Bar onsite, Gender-neutral restroom, Restroom, Wi-Fi                                   3
# High chairs, Wi-Fi                                                                     2
# Bar onsite, Good for kids, Wi-Fi                                                       2
# Bar onsite, Gender-neutral restroom, Restroom                                          2
# Bar onsite, Gender-neutral restroom, Wi-Fi                                             2
# Bar onsite, Gender-neutral restroom, Good for kids, High chairs, Restroom              2
# Bar onsite, Gender-neutral restroom, Good for kids, Restroom, Wi-Fi                    2
# Restroom, Wi-Fi                                                                        2
# Gender-neutral restroom, Good for kids, Restroom, Wi-Fi                                2
# High chairs, Restroom, Wi-Fi                                                           2
# Bar onsite, Gender-neutral restroom, High chairs, Restroom, Wi-Fi                      1
# Bar onsite, Gender-neutral restroom, High chairs, Restroom                             1
# Bar onsite, Gender-neutral restroom, Good for kids, Wi-Fi                              1
# Bar onsite, Gender-neutral restroom, Good for kids, Restroom                           1
# Gender-neutral restroom, Wi-Fi                                                         1
# Gender-neutral restroom, Restroom, Wi-Fi                                               1
# Gender-neutral restroom, Good for kids, Wi-Fi                                          1
# Bar onsite, Gender-neutral restroom, Good for kids, High chairs                        1
# Gender-neutral restroom, Restroom                                                      1
# Bar onsite, Gender-neutral restroom                                                    1
# Name: Amenities, dtype: int64
# Total Count: 2114
#
# Value Counts for Service options:
# Delivery                                                                             693
# Takeout, Delivery                                                                    330
# Takeout, Dine-in, Delivery                                                           296
# Delivery, Takeout, Dine-in                                                           212
# Delivery, Takeout                                                                    130
#                                                                                     ...
# Curbside pickup, Takeout, Delivery                                                     1
# Outdoor seating, Curbside pickup, No-contact delivery, Takeout, Delivery, Dine-in      1
# Curbside pickup, Delivery, Drive-through, Takeout                                      1
# Curbside pickup, No-contact delivery, Drive-through, Takeout, Delivery, Dine-in        1
# Outdoor seating, Curbside pickup, Takeout, Delivery                                    1
# Name: Service options, Length: 73, dtype: int64
# Total Count: 2531
#
# Value Counts for Planning:
# Accepts reservations                                                                     331
# Dinner reservations recommended, Accepts reservations                                     22
# Usually a wait                                                                             2
# Lunch reservations recommended, Dinner reservations recommended, Accepts reservations      1
# Lunch reservations recommended, Accepts reservations                                       1
# Dinner reservations recommended                                                            1
# Accepts reservations, Usually a wait                                                       1
# Name: Planning, dtype: int64
# Total Count: 359

# %%
metdat_florida.drop(columns=['Planning', 'Payments', 'Highlights'], inplace=True)

# %% [markdown]
# ## 5. Columna Hours

# %%
print(metdat_florida.iloc[3]['hours'])
print(type(metdat_florida.iloc[3]['hours']))
# Out:
# [['Thursday', '8:30AM–10PM'], ['Friday', '7AM–11PM'], ['Saturday', '9AM–11PM'], ['Sunday', '9AM–10PM'], ['Monday', '8:30AM–10PM'], ['Tuesday', '8:30AM–10PM'], ['Wednesday', '8:30AM–10PM']]
# <class 'str'>

# %%
import ast
# De <class 'str'> a <class 'list'>

metdat_florida['hours'] = metdat_florida['hours'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# De <class 'list'> a <class 'dict'>

metdat_florida['hours'] = metdat_florida['hours'].apply(lambda x: dict(x) if isinstance(x, list) else x)

# De <class 'dict'> a columnas

hours_df = metdat_florida['hours'].apply(pd.Series)

# Concatenamos las columnas

metdat_florida = pd.concat([metdat_florida, hours_df], axis=1)

metdat_florida = metdat_florida.drop(columns=['hours', 0])

metdat_florida.head(3)
# Out:
#                     name                                            address  \
# 114   Cape Seafood Shack  Cape Seafood Shack, 603 Del Prado Blvd S, Cape...
# 674              Hot Box      Hot Box, 1-99 Kinkaid St, Pensacola, FL 32507
# 2438        Bachata Rosa    Bachata Rosa, 887w W 29th St, Hialeah, FL 33012
#
#                                     gmap_id description   latitude  longitude  \
# 114   0x88db4147b1d9e6f3:0x943dbd10a92ba1b1         NaN  26.641377 -81.940545
# 674   0x8890b9241e704667:0x3a1e565c17c00993         NaN  30.391411 -87.267220
# 2438  0x88d9ba5d65937567:0xbc27649cf513cc89         NaN  25.848173 -80.299773
#
#         category  avg_rating  num_of_reviews price  ...   Crowd Atmosphere  \
# 114   Restaurant         5.0               1    $$  ...     NaN     Casual
# 674   Restaurant         4.2               5   NaN  ...     NaN        NaN
# 2438  Restaurant         3.6               8   NaN  ...  Groups     Casual
#
#           Amenities    Thursday      Friday    Saturday   Sunday      Monday  \
# 114   Good for kids         NaN         NaN         NaN      NaN         NaN
# 674             NaN  6:30AM–6PM  6:30AM–6PM  6:30AM–6PM   Closed  6:30AM–6PM
# 2438            NaN     6PM–1AM     6PM–1AM     6PM–1AM  6PM–1AM     6PM–1AM
#
#          Tuesday   Wednesday
# 114          NaN         NaN
# 674   6:30AM–6PM  6:30AM–6PM
# 2438     6PM–1AM      Closed
#
# [3 rows x 29 columns]

# %%
metdat_florida.iloc[0]
# Out:
# name                                              Cape Seafood Shack
# address            Cape Seafood Shack, 603 Del Prado Blvd S, Cape...
# gmap_id                        0x88db4147b1d9e6f3:0x943dbd10a92ba1b1
# description                                                      NaN
# latitude                                                   26.641377
# longitude                                                 -81.940545
# category                                                  Restaurant
# avg_rating                                                       5.0
# num_of_reviews                                                     1
# price                                                             $$
# state                                                            NaN
# city                                                      Cape Coral
# states                                                            FL
# postal_code                                                  33990.0
# Service options                                    Dine-in, Delivery
# Popular for                                                      NaN
# Accessibility      Wheelchair accessible entrance, Wheelchair acc...
# Offerings                                               Comfort food
# Dining options                                         Lunch, Dinner
# Crowd                                                            NaN
# Atmosphere                                                    Casual
# Amenities                                              Good for kids
# Thursday                                                         NaN
# Friday                                                           NaN
# Saturday                                                         NaN
# Sunday                                                           NaN
# Monday                                                           NaN
# Tuesday                                                          NaN
# Wednesday                                                        NaN
# Name: 114, dtype: object

# %%
metdat_florida.fillna('sin datos')
# Out:
#                                     name  \
# 114                   Cape Seafood Shack
# 674                              Hot Box
# 2438                        Bachata Rosa
# 3258                   Zampini's Bottega
# 3449                        Choices Cafe
# ...                                  ...
# 2992530  Me Hungry Vegetarian Restaurant
# 2993203               Grain & Berry Cafe
# 2993233     The Club at Key West Harbour
# 2996034       Daniel's Cheesesteak House
# 2998098     Bakery Antojitos Colombianos
#
#                                                    address  \
# 114      Cape Seafood Shack, 603 Del Prado Blvd S, Cape...
# 674          Hot Box, 1-99 Kinkaid St, Pensacola, FL 32507
# 2438       Bachata Rosa, 887w W 29th St, Hialeah, FL 33012
# 3258     Zampini's Bottega, 510 SE 5th Ave, Fort Lauder...
# 3449        Choices Cafe, 711 NW 27th Ave, Miami, FL 33125
# ...                                                    ...
# 2992530  Me Hungry Vegetarian Restaurant, 105 N State R...
# 2993203  Grain & Berry Cafe, 2722 N Roosevelt Blvd, Key...
# 2993233  The Club at Key West Harbour, 6000 Peninsular ...
# 2996034  Daniel's Cheesesteak House, 978 E Plant St, Wi...
# 2998098  Bakery Antojitos Colombianos, 12161 SW 152nd S...
#
#                                        gmap_id  \
# 114      0x88db4147b1d9e6f3:0x943dbd10a92ba1b1
# 674      0x8890b9241e704667:0x3a1e565c17c00993
# 2438     0x88d9ba5d65937567:0xbc27649cf513cc89
# 3258      0x88d900575f0dd065:0x9b3638d2a80be4d
# 3449     0x88d9b719170a9f61:0x30d454a980f76ad3
# ...                                        ...
# 2992530  0x88d90724bd1aaaa9:0xcddf8a58b3167313
# 2993203  0x88d1b1952d3820b7:0x3cb6313204ef404f
# 2993233  0x88d1b19a291afb27:0xc996708404476f68
# 2996034  0x88e783dedf1bcaeb:0xba9e5f8779cf4591
# 2998098  0x88d9c3c682fe8a01:0x34f123db79ec201e
#
#                                                description   latitude  \
# 114                                              sin datos  26.641377
# 674                                              sin datos  30.391411
# 2438                                             sin datos  25.848173
# 3258                                             sin datos  26.116549
# 3449     Quaint cafe with a changing daily menu focused...  25.779837
# ...                                                    ...        ...
# 2992530                                          sin datos  26.121813
# 2993203                                          sin datos  24.564509
# 2993233                                          sin datos  24.564275
# 2996034                                          sin datos  28.568100
# 2998098                                          sin datos  25.627098
#
#          longitude    category  avg_rating  num_of_reviews      price  ...  \
# 114     -81.940545  Restaurant         5.0               1         $$  ...
# 674     -87.267220  Restaurant         4.2               5  sin datos  ...
# 2438    -80.299773  Restaurant         3.6               8  sin datos  ...
# 3258    -80.138561  Restaurant         4.7              18  sin datos  ...
# 3449    -80.239103  Restaurant         4.6              45          $  ...
# ...            ...         ...         ...             ...        ...  ...
# 2992530 -80.202066  Restaurant         4.4             118         $$  ...
# 2993203 -81.772586  Restaurant         4.3             106         $$  ...
# 2993233 -81.726255  Restaurant         3.9               7  sin datos  ...
# 2996034 -81.572432  Restaurant         4.7             288          $  ...
# 2998098 -80.389759  Restaurant         4.5              46  sin datos  ...
#
#                     Crowd    Atmosphere             Amenities     Thursday  \
# 114             sin datos        Casual         Good for kids    sin datos
# 674             sin datos     sin datos             sin datos   6:30AM–6PM
# 2438               Groups        Casual             sin datos      6PM–1AM
# 3258      Family-friendly     sin datos             sin datos  8:30AM–10PM
# 3449            sin datos     sin datos         Good for kids    sin datos
# ...                   ...           ...                   ...          ...
# 2992530  Groups, Tourists  Casual, Cozy         Good for kids     11AM–9PM
# 2993203          Tourists  Casual, Cozy         Good for kids      8AM–8PM
# 2993233   Family-friendly     sin datos  Bar onsite, Restroom     11AM–9PM
# 2996034            Groups        Casual         Good for kids      7AM–7PM
# 2998098         sin datos     sin datos         Good for kids   7:30AM–5PM
#
#              Friday    Saturday     Sunday       Monday      Tuesday  \
# 114       sin datos   sin datos  sin datos    sin datos    sin datos
# 674      6:30AM–6PM  6:30AM–6PM     Closed   6:30AM–6PM   6:30AM–6PM
# 2438        6PM–1AM     6PM–1AM    6PM–1AM      6PM–1AM      6PM–1AM
# 3258       7AM–11PM    9AM–11PM   9AM–10PM  8:30AM–10PM  8:30AM–10PM
# 3449      sin datos   sin datos  sin datos    sin datos    sin datos
# ...             ...         ...        ...          ...          ...
# 2992530    11AM–6PM      Closed     Closed     11AM–9PM     11AM–9PM
# 2993203     8AM–8PM     8AM–8PM    8AM–8PM      8AM–8PM      8AM–8PM
# 2993233    11AM–9PM    11AM–9PM   11AM–9PM     11AM–9PM     11AM–9PM
# 2996034     7AM–7PM     7AM–7PM     Closed      7AM–7PM      7AM–7PM
# 2998098  7:30AM–5PM  7:30AM–5PM     Closed   7:30AM–5PM   7:30AM–5PM
#
#            Wednesday
# 114        sin datos
# 674       6:30AM–6PM
# 2438          Closed
# 3258     8:30AM–10PM
# 3449       sin datos
# ...              ...
# 2992530     11AM–9PM
# 2993203      8AM–8PM
# 2993233     11AM–9PM
# 2996034      7AM–7PM
# 2998098   7:30AM–5PM
#
# [2554 rows x 29 columns]

# %%
metdat_florida.to_csv('/content/drive/MyDrive/Otros/googlemaps_metadata_sitios_florida.csv', index=False)

# %%
metdat_florida['price'].value_counts()
# Out:
# $$     240
# $      162
# $$$     11
# Name: price, dtype: int64

# %% [markdown]
# # Author: Max J.
